# %% [markdown]
# # Gaussian fits for gamma ray data
#
# $$ \text{Equation for gaussian fit: }f(x) = Ae^{-\frac{(x-B)^2}{2C^2}} + D$$
#
# Where $A$ is the amplitude/count of the peak, $B$ is the mean/channel number, $C$ is the standard deviation/width of the gaussian fit, and $D$ is a vertical offset.

# %%
import numpy as np 
import pylab as py
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

#import csv

# Defining the equation for the gaussina fit given a above
def fgaussian(x, A, B, C, D):
    return A * np.exp(-((x - B) ** 2) / (2 * C ** 2)) + D

# Make sure dtype is float
def is_float(string): 
    try:
        float(string)
        return True
    except ValueError:
        return False
    
data1 = np.genfromtxt('DataCSVFiles/Ba-133data.csv', delimiter=',', skip_header=22, dtype=str)
data2 = np.genfromtxt('DataCSVFiles/Cd-109data.csv', delimiter=',', skip_header=22, dtype=str)
data3 = np.genfromtxt('DataCSVFiles/Co-57data.csv', delimiter=',', skip_header=22, dtype=str)
data4 = np.genfromtxt('DataCSVFiles/Co-60data.csv', delimiter=',', skip_header=22, dtype=str)
data5 = np.genfromtxt('DataCSVFiles/Mn-54data.csv', delimiter=',', skip_header=22, dtype=str)
data6 = np.genfromtxt('DataCSVFiles/Na-22data.csv', delimiter=',', skip_header=22, dtype=str)
data7 = np.genfromtxt('DataCSVFiles/Unknowndata.csv', delimiter=',', skip_header=22, dtype=str)

x_data_1 = [float(row[0]) if is_float(row[0]) else np.nan for row in data1]
y_data_1 = [float(row[2]) if is_float(row[2]) else np.nan for row in data1]
x_data_2 = [float(row[0]) if is_float(row[0]) else np.nan for row in data2]
y_data_2 = [float(row[2]) if is_float(row[2]) else np.nan for row in data2]
x_data_3 = [float(row[0]) if is_float(row[0]) else np.nan for row in data3]
y_data_3 = [float(row[2]) if is_float(row[2]) else np.nan for row in data3]
x_data_4 = [float(row[0]) if is_float(row[0]) else np.nan for row in data4]
y_data_4 = [float(row[2]) if is_float(row[2]) else np.nan for row in data4]
x_data_5 = [float(row[0]) if is_float(row[0]) else np.nan for row in data5]
y_data_5 = [float(row[2]) if is_float(row[2]) else np.nan for row in data5]
x_data_6 = [float(row[0]) if is_float(row[0]) else np.nan for row in data6]
y_data_6 = [float(row[2]) if is_float(row[2]) else np.nan for row in data6]
x_data_7 = [float(row[0]) if is_float(row[0]) else np.nan for row in data7]
y_data_7 = [float(row[2]) if is_float(row[2]) else np.nan for row in data7]

# %% [markdown]
# ## Ba-133:

# %%
params, covariance = curve_fit(fgaussian, x_data_1[0:75], y_data_1[0:75], p0=[47130, 56, 25, 0]) # peak 1

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_1, y_data_1, label='Data', marker='.')
x_fit = np.linspace(min(x_data_1), max(x_data_1), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Ba-133, Peak 1')
plt.legend()
plt.show()

print('Peak 1 (0.081 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (0.081 MeV):
#
# A = 44962.23036140 ± 383.84802710
# B = 56.00504192 ± 0.05140962
# C = 5.39344028 ± 0.05637952
# D = 588.27456353 ± 137.43412890

# %%
params, covariance = curve_fit(fgaussian, x_data_1[130:180], y_data_1[130:180], p0=[11706, 154, 22, 0]) # peak 2


A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_1, y_data_1, label='Data', marker='.')
x_fit = np.linspace(min(x_data_1), max(x_data_1), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Ba-133, Peak 2')
plt.legend()
plt.show()

print('Peak 2 (0.276 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 2 (0.276 MeV):
#
# A = 10557.24186435 ± 198.38134303
# B = 152.07904467 ± 0.13857328
# C = 8.09360430 ± 0.21915199
# D = 1046.23854026 ± 164.73884274

# %%
params, covariance = curve_fit(fgaussian, x_data_1[200:230], y_data_1[200:230], p0=[1284, 218, 14, 0]) # peak 3

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_1, y_data_1, label='Data', marker='.')
x_fit = np.linspace(min(x_data_1), max(x_data_1), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Ba-133, Peak 3')
plt.legend()
plt.show()

print('Peak 3 (0.303 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 3 (0.303 MeV):
#
# A = 624.18234695 ± 41.47662307
# B = 216.34200380 ± 0.14527638
# C = 8.22641323 ± 0.56648059
# D = 639.27764160 ± 44.67268120

# %%
params, covariance = curve_fit(fgaussian, x_data_1[400:550], y_data_1[400:550], p0=[1267, 519, 19, 0]) # peak 4

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_1, y_data_1, label='Data', marker='.')
x_fit = np.linspace(min(x_data_1), max(x_data_1), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Ba-133, Peak 4')
plt.legend()
plt.show()

print('Peak 4 (0.356 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 4 (0.356 MeV):
#
# A = 867.42290399 ± 11.56768680
# B = 513.31735213 ± 0.44168567
# C = 30.65789778 ± 0.63422356
# D = 274.76826519 ± 9.02823338

# %%
params, covariance = curve_fit(fgaussian, x_data_1[550:630], y_data_1[550:630], p0=[2832, 603, 37, 0]) # peak 5

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_1, y_data_1, label='Data', marker='.')
x_fit = np.linspace(min(x_data_1), max(x_data_1), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Ba-133, Peak 5')
plt.legend()
plt.show()

print('Peak 5 (0.384 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 5 (0.384 MeV):
#
# A = 2336.15363276 ± 32.13955801
# B = 602.17487763 ± 0.14672040
# C = 22.57113753 ± 0.37785575
# D = 439.39311777 ± 34.51641383

# %% [markdown]
# ## Cd-109:

# %%
params, covariance = curve_fit(fgaussian, x_data_2[100:250], y_data_2[100:250], p0=[482, 162, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_2, y_data_2, label='Data', marker='.')
x_fit = np.linspace(min(x_data_2), max(x_data_2), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Cd-109')
plt.legend()
plt.show()

print('Peak 1 (0.088 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (0.088 MeV):
#
# A = 372.39654238 ± 8.13680523
# B = 163.63746934 ± 0.22455563
# C = 9.13387791 ± 0.24181328
# D = 82.05262029 ± 2.58632978

# %% [markdown]
# ## Co-57:

# %%
params, covariance = curve_fit(fgaussian, x_data_3[0:2047], y_data_3[0:2047], p0=[482, 162, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_3, y_data_3, label='Data', marker='.')
x_fit = np.linspace(min(x_data_3), max(x_data_3), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Co-57')
plt.legend()
plt.show()

print('Peak 1 (0.122 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (0.122 MeV):
#
# A = 1474.39578776 ± 10.36676788
# B = 224.59664836 ± 0.09921568
# C = 12.24210767 ± 0.09975734
# D = 18.99417774 ± 0.88406999

# %% [markdown]
# ## Co-60:

# %%
params, covariance = curve_fit(fgaussian, x_data_4[1500:1700], y_data_4[1500:1700], p0=[100, 1700, 20, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_4, y_data_4, label='Data', marker='.')
x_fit = np.linspace(min(x_data_4), max(x_data_4), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Co-60, Peak 1')
plt.legend()
plt.show()

print('Peak 1 (1.175 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (1.175 MeV):
#
# A = 204.19550549 ± 2.21120290
# B = 1679.79194564 ± 0.62651287
# C = 28.41017909 ± 0.64832378
# D = 94.24755943 ± 1.09934122

# %%
params, covariance = curve_fit(fgaussian, x_data_4[1750:2047], y_data_4[1750:2047], p0=[100, 1850, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_4, y_data_4, label='Data', marker='.')
x_fit = np.linspace(min(x_data_4), max(x_data_4), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Co-60, Peak 2')
plt.legend()
plt.show()

print('Peak 1 (1.333 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (1.333 MeV):
#
# A = 206.13444275 ± 2.20633327
# B = 1862.93843252 ± 0.42154445
# C = 37.93124316 ± 0.54038151
# D = 13.22599934 ± 1.33261183

# %% [markdown]
# ## Mn-54:

# %%
params, covariance = curve_fit(fgaussian, x_data_5[1100:1500], y_data_5[1100:1500], p0=[100, 1200, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_5, y_data_5, label='Data', marker='.')
x_fit = np.linspace(min(x_data_5), max(x_data_5), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Mn-54')
plt.legend()
plt.show()

print('Peak 1 (0.835 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (0.835 MeV):
#
# A = 115.20776469 ± 0.93839575
# B = 1258.88557067 ± 0.28846299
# C = 31.90004980 ± 0.32192033
# D = 4.57952329 ± 0.36494554

# %% [markdown]
# ## Na-22:

# %%
params, covariance = curve_fit(fgaussian, x_data_6[600:1000], y_data_6[600:1000], p0=[500, 840, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_6, y_data_6, label='Data', marker='.')
x_fit = np.linspace(min(x_data_6), max(x_data_6), 4000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Na-22, Peak 1')
plt.legend()
plt.show()

print('Peak 1 (0.511 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (0.511 MeV):
#
# A = 421.61567419 ± 2.33236363
# B = 832.72160507 ± 0.15945559
# C = 25.67098521 ± 0.17267498
# D = 29.99758985 ± 0.76951768

# %%
params, covariance = curve_fit(fgaussian, x_data_6[1700:2047], y_data_6[1700:2047], p0=[0, 1800, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_6, y_data_6, label='Data', marker='.')
x_fit = np.linspace(min(x_data_6), max(x_data_6), 4000)
#x_fit = np.linspace(x_data_6[1700], x_data_6[2047], 1000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Na-22, Peak 2')
plt.legend()
plt.show()

print('Peak 2 (1.115 MeV):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 2 (1.115 MeV):
#
# A = 49.21059976 ± 0.67976873
# B = 1788.49117696 ± 0.54799533
# C = 36.89340329 ± 0.63712754
# D = 3.87372230 ± 0.32472062

# %% [markdown]
# ## Finding a linear fit for gamma ray energy [MeV] vs. channel number for known energies.
#
# $$ \text{Equation for linear fit: } C = mE + b$$
#
# Where $C$ is the count, $E$ is the gamma ray energy, $m$ is the slope, and $b$ is the y-intercept.
#
# | Material | Energy [MeV] | Channel ± Error           |
# |----------|--------------|---------------------------|
# | Ba-133   | 0.081        | 56.00504192 ± 0.05140962  |
# | Cd-109   | 0.088        | 163.63746934 ± 0.22455563 |
# | Co-57    | 0.122        | 224.59664836 ± 0.09921568 |
# | Ba-133   | 0.276        | 152.07904467 ± 0.13857328 |
# | Ba-133   | 0.303        | 216.34200380 ± 0.14527638 |
# | Ba-133   | 0.356        | 513.31735213 ± 0.44168567 |
# | Ba-133   | 0.384        | 602.17487763 ± 0.14672040 |
# | Na-22    | 0.511        | 832.72160507 ± 0.15945559 |
# | Mn-54    | 0.835        | 1258.88557067 ± 0.28846299|
# | Na-22    | 1.115        | 1788.49117696 ± 0.54799533|
# | Co-60    | 1.175        | 1679.79194564 ± 0.62651287|
# | co-60    | 1.333        | 1862.93843252 ± 0.42154445|
#
# In the cell below, we take these data points and use linear regression to find a linear line of best fit, as well as the combined error of the $C$ values, the standard error of the slope $m$, and the error in the intercept $b$. Then after solving the equation for linear fit for $E$ and taking its partials, we can then use use the formula below to solve for the error in the energy $E$.
#
# $$ \text{Equation for propagation of error: } (\sigma_{E})^2 = \Sigma^{3}_{i=1}\biggl(\sigma_i \frac{\partial E}{\partial a_i}\biggr)^2 = \biggl(\sigma_C \frac{\partial E}{\partial C} \biggr)^2 + \biggl(\sigma_m \frac{\partial E}{\partial m}  \biggr)^2 + \biggl(\sigma_b \frac{\partial E}{\partial b} \biggr)^2$$
#
# $$ \text{Linear fit equation solved for E: } \hspace{0.2cm} E = \frac{C - b}{m}  $$
#
# $$ \frac{\partial E}{\partial C} = \frac{1}{m} \hspace{1cm} \frac{\partial E}{\partial m} = -\frac{C - b}{m^2} \hspace{1cm} \frac{\partial E}{\partial b} = -\frac{1}{m} $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

E_data = np.array([0.081, 0.088, 0.122, 0.276, 
                   0.303, 0.356, 0.384, 0.511, 
                   0.835, 1.115, 1.175, 1.333])

C_data = np.array([56.00504192, 163.63746934, 224.59664836, 152.07904467, 
                   216.34200380, 513.31735213, 602.17487763, 832.72160507, 
                   1258.88557067, 1788.49117696, 1679.79194564, 1862.93843252])

C_errors = np.array([0.05140962, 0.22455563, 0.09921568, 0.13857328, 
                    0.14527638, 0.44168567, 0.14672040, 0.15945559,
                    0.28846299, 0.54799533, 0.62651287, 0.42154445])

C_error = (np.sum(C_errors**2))**(1/2)

slope, intercept, r_value, p_value, std_err = stats.linregress(E_data, C_data)

result = stats.linregress(E_data, C_data)

data_labels = ['Ba-133', 'Cd-109', 'Co-57', 'Ba-133', 'Ba-133', 'Ba-133',
               'Ba-133', 'Na-22', 'Mn-54', 'Na-22', 'Co-60', 'Co-60']

for x, y, label in zip(E_data, C_data, data_labels):
    plt.text(x, y, label, fontsize=9, ha='left', va='top')

res = stats.linregress(E_data, C_data)
plt.plot(E_data, C_data, '.', color='blue', label='data points')
plt.plot(E_data, res.intercept + res.slope*E_data, 'r', label='fitted line')
plt.xlabel('Energy [MeV]')
plt.ylabel('Channel')
plt.title('Energy vs. count for gamma ray sources')
plt.grid(True)
plt.legend()
plt.show()

print(f"Linear fit: C = ({res.slope:.8f}+/-{result.stderr:.8f})E + ({res.intercept:.8f}+/-{result.intercept_stderr:.8f})")
print()
print(f'Error for counts (C) = {C_error:.8f}')
#print(f'm = {result.slope} +/- {result.stderr}') # prints off the slope and standard error of the slope
#print()
#print(f'b = {result.intercept} +/- {result.intercept_stderr}') # prints off the intercept and the error of the intercept
# Out:
# Linear fit: C = (1515.20223699+/-83.22041719)E + (-51.46119571+/-58.00832702)
#
# Error for counts (C) = 1.13973101

# %% [markdown]
# $$ m = 1515.20223699 \text{ MeV}^{-1} \hspace{1cm} b = -51.46119571 \text{ unitless?}$$
#
#
# Errors for $C$, $m$, and $b$.
#
# $$ \sigma_C = 1.13973101 \text{ unitless?} \hspace{1cm} \sigma_m = 83.22041719 \text{ MeV}^{-1} \hspace{1cm} \sigma_b = 58.00832702 \text{ unitless?}$$

# %%
# Errors for E

sigma_C = C_error # Note: The errors the we get for the values of E vary only slightly if we use C_errors or C_errors
# Maybe that means the combinations of the C errors was an unnecessary step? 

sigma_m = 83.22041719 #MeV^-1, error for slope
sigma_b = 58.00832702 # error for intercept 
m = 1515.20223699
b = -51.46119571

partial_w_respect_to_C = 1/m
partial_w_respect_to_m = -(C_data - b)/m**2
partial_w_respect_to_b = -1/m

# errors for the energies
sigma_E = ((sigma_C * partial_w_respect_to_C)**2 
           + (sigma_m * partial_w_respect_to_m)**2 
           + (sigma_b * partial_w_respect_to_b)**2)**0.5
sigma_E
# Out:
# array([0.03848924, 0.03907736, 0.03957752, 0.03899592, 0.03950293,
#        0.04342076, 0.04502907, 0.04993458, 0.06101068, 0.07690586,
#        0.07351499, 0.07925755])

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(E_data, C_data)

result = stats.linregress(E_data, C_data)

data_labels = ['Ba-133', 'Cd-109', 'Co-57', 'Ba-133', 'Ba-133', 'Ba-133',
               'Ba-133', 'Na-22', 'Mn-54', 'Na-22', 'Co-60', 'Co-60']

for x, y, label in zip(E_data, C_data, data_labels):
    plt.text(x, y, label, fontsize=9, ha='left', va='top')

res = stats.linregress(E_data, C_data)
#plt.plot(E_data, C_data, '.', label='data points')
plt.plot(E_data, res.intercept + res.slope*E_data, 'r', label='fitted line')
plt.errorbar(E_data, C_data, xerr=sigma_E, yerr=C_errors, fmt='.', color='blue', label='Data points with Error Bars', markersize=5, capsize=3)
plt.xlabel('Energy [MeV]')
plt.ylabel('Channel')
plt.title('Energy vs. count for gamma ray sources')
plt.grid(True)
plt.legend()
plt.show()

print(f"Linear fit: C = ({res.slope:.8f} ± {result.stderr:.8f})E + ({res.intercept:.8f} ± {result.intercept_stderr:.8f})")
print()
#print(f'Error for counts (C) = {C_error:.8f}')
# Out:
# Linear fit: C = (1515.20223699 ± 83.22041719)E + (-51.46119571 ± 58.00832702)

# %% [markdown]
# Since we have those two Ba-133 peaks that don't overlap with the fit line at all, I wonder if we should go back and try to pick better candidates for actual gamma ray pulses.

# %% [markdown]
# ## Unknown:

# %%
params, covariance = curve_fit(fgaussian, x_data_7[600:2047], y_data_7[600:2047], p0=[0, 1000, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_7, y_data_7, label='Data', marker='.')
x_fit = np.linspace(min(x_data_7), max(x_data_7), 4000)
#x_fit = np.linspace(x_data_6[1700], x_data_6[2047], 1000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Unknown, Peak 1')
plt.legend()
plt.show()

print('Peak 1 (unknown energy):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 1 (unknown energy):
#
# A = 1118.94128352 ± 11.74808314
# B = 1037.25374422 ± 0.32953887
# C = 27.34907529 ± 0.33561948
# D = 40.32006839 ± 1.83980452

# %%
params, covariance = curve_fit(fgaussian, x_data_7[1500:2047], y_data_7[1500:2047], p0=[0, 1600, 10, 0])

A_fit, B_fit, C_fit, D_fit = params

A_err, B_err, C_err, D_err = np.sqrt(np.diag(covariance))

plt.scatter(x_data_7, y_data_7, label='Data', marker='.')
x_fit = np.linspace(min(x_data_7), max(x_data_7), 4000)
#x_fit = np.linspace(x_data_6[1700], x_data_6[2047], 1000)
y_fit = fgaussian(x_fit, A_fit, B_fit, C_fit, D_fit)
plt.plot(x_fit, y_fit, label='Best Fit', color='red')
plt.xlabel('Channel')
plt.ylabel('Count')
plt.title('Unknown, Peak 2')
plt.legend()
plt.show()

print('Peak 2 (unknown energy):')
print()
print(f'A = {A_fit:.8f} ± {A_err:.8f}')
print(f'B = {B_fit:.8f} ± {B_err:.8f}')
print(f'C = {C_fit:.8f} ± {C_err:.8f}')
print(f'D = {D_fit:.8f} ± {D_err:.8f}')
# Out:
# Peak 2 (unknown energy):
#
# A = 14.33916890 ± 0.35473895
# B = 1606.71305445 ± 1.09401237
# C = 39.71124574 ± 1.19390248
# D = 2.49471712 ± 0.12622173

# %% [markdown]
# ## Linear fit with unknown quantities
#
# * Unknown, peak 1:
#
# $ (E_{1}, 1037.25374422 ± 0.32953887) $
#
# * Unknown, peak 2:
#
# $(E_{2}, 1606.71305445 ± 1.09401237)$
#
# $ C = mE+b \rightarrow E = \frac{C - b}{m}$

# %%
# calculations for unknown peaks
 
# Channel number for each peak and errors
C1 = 1037.25374422
C2 = 1606.71305445
m = 1515.20223699
b = -51.46119571
sigma_C1 = 0.32953887
sigma_C2 = 1.09401237
sigma_m = 83.22041719 #MeV^-1
sigma_b = 58.00832702 

partial_w_respect_to_C = 1/m
partial_w_respect_to_m_for_C1 = -(C1 - b)/m**2
partial_w_respect_to_m_for_C2 = -(C2 - b)/m**2
partial_w_respect_to_b = -1/m
    
# peak 1
E1 = (C1 - (-51.46119571))/1515.20223699 
sigma_E1 = ((sigma_C1 * partial_w_respect_to_C)**2 
           + (sigma_m * partial_w_respect_to_m_for_C1)**2 
           + (sigma_b * partial_w_respect_to_b)**2)**0.5 

# peak 2
E2 = (C2 - (-51.46119571))/1515.20223699
sigma_E2 = ((sigma_C2 * partial_w_respect_to_C)**2 
           + (sigma_m * partial_w_respect_to_m_for_C2)**2 
           + (sigma_b * partial_w_respect_to_b)**2)**0.5 

print(f'Peak 1 is at (E1, C1) = ({E1} ± {sigma_E1}, {C1} ± {sigma_C1})')
print()
print(f'Peak 2 is at (E2, C2) = ({E2} ± {sigma_E2}, {C2} ± {sigma_C2})')
# Out:
# Peak 1 is at (E1, C1) = (0.7185278066199062 ± 0.05498316378902933, 1037.25374422 ± 0.32953887)
#
# Peak 2 is at (E2, C2) = (1.094358369912401 ± 0.07126675680880996, 1606.71305445 ± 1.09401237)

# %%
E_data_w_unknown = np.array([0.081, 0.088, 0.122, 
                       0.276, 0.303, 0.356, 
                       0.384, 0.511, 0.835, 
                       1.115, 1.175, 1.333, 
                       0.7185278066199062, 1.094358369912401])

C_data_w_unknown = np.array([56.00504192, 163.63746934, 224.59664836, 
                       152.07904467, 216.34200380, 513.31735213,
                       602.17487763, 832.72160507, 1258.88557067, 
                       1788.49117696, 1679.79194564, 1862.93843252,
                       1037.25374422, 1606.71305445])

C_errors_w_unknown = np.array([0.05140962, 0.22455563, 0.09921568, 
                               0.13857328, 0.14527638, 0.44168567, 
                               0.14672040, 0.15945559, 0.28846299, 
                               0.54799533, 0.62651287, 0.42154445,
                               0.32953887, 1.09401237])

sigma_C = C_errors_w_unknown
sigma_m = 83.22041719 #MeV^-1, error for slope
sigma_b = 58.00832702 # error for intercept 
m = 1515.20223699
b = -51.46119571

partial_w_respect_to_C = 1/m
partial_w_respect_to_m = -(C_data_w_unknown - b)/m**2
partial_w_respect_to_b = -1/m

sigma_E_w_unknown = ((sigma_C * partial_w_respect_to_C)**2 
           + (sigma_m * partial_w_respect_to_m)**2 
           + (sigma_b * partial_w_respect_to_b)**2)**0.5

slope, intercept, r_value, p_value, std_err = stats.linregress(E_data, C_data)

result = stats.linregress(E_data_w_unknown, C_data_w_unknown)

data_labels_w_unknown = ['Ba-133', 'Cd-109', 'Co-57', 'Ba-133', 'Ba-133', 'Ba-133',
               'Ba-133', 'Na-22', 'Mn-54', 'Na-22', 'Co-60', 'Co-60', 'Unknown 1', 'Unknown 2']

for x, y, label in zip(E_data_w_unknown, C_data_w_unknown, data_labels_w_unknown):
    plt.text(x, y, label, fontsize=9, ha='left', va='top')
    
res_w_unknown = stats.linregress(E_data_w_unknown, C_data_w_unknown)

plt.plot(E_data_w_unknown, res_w_unknown.intercept + res_w_unknown.slope*E_data_w_unknown, 'r', label='fitted line')
plt.errorbar(E_data_w_unknown, C_data_w_unknown, xerr=sigma_E_w_unknown, yerr=C_errors_w_unknown, fmt='.', color='blue', label='Data points with Error Bars', markersize=5, capsize=3)
plt.xlabel('Energy [MeV]')
plt.ylabel('Channel')
plt.title('Energy vs. count for gamma ray sources')
plt.grid(True)
plt.legend()
plt.show()

print(f"Linear fit: C = ({res_w_unknown.slope:.8f} ± {result.stderr:.8f})E + ({res_w_unknown.intercept:.8f} ± {result.intercept_stderr:.8f})")
print()
# Out:
# Linear fit: C = (1515.20223699 ± 71.44456834)E + (-51.46119571 ± 52.44646391)
