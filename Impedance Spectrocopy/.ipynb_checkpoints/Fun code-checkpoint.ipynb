# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = np.genfromtxt('ImpedanceSpecData3_18_24_R0aRun1.txt', delimiter=',', skip_header=4, dtype=float)


omega = data[:,0]
sigma_omega = data[:,1]

voltage = data[:,2]
sigma_voltage = data[:,3]

R0a = 10000 # Ohms
R1 = 200
R2 = 20
C2 = 0.22e-6 # Farads

f = omega/(2*np.pi)

omega_c = (C2*(R1 + R2))**(-1)
f_c = omega_c/(2*np.pi)

tau = omega/omega_c
r = R1/R2

z = np.sqrt(((1+tau*(1/(1+r)))**2 + (tau*(r/(1+r)))**2)/(1+tau**2)**2)*R1
z_tot = R0a + z 

plt.xscale('log')
plt.plot(f, z)

# %%
omega
# Out:
# array([   100.,    280.,    460.,    640.,    820.,   1000.,   2800.,
#          4600.,   6400.,   8200.,  10000.,  28000.,  46000.,  64000.,
#         82000., 100000.])
